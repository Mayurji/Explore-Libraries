# %%
import seaborn
import pandas as pd

# %%
d = {"tasks": ["read_csv", "read_csv", "reverse", "reverse", "drop", "drop", "merge", "merge", "concat", "concat"],
     "time" : [0.92259, 26.84219, 0.00809, 2.30518, 1.15515, 98.58453, 0.89333, 59.11782, 0.09226, 4.06770],
     "lib": ["cuDF", "Pandas", "cuDF", "Pandas", "cuDF", "Pandas", "cuDF", "Pandas", "cuDF", "Pandas"]}

# %%
cudf_pd = pd.DataFrame.from_dict(d)

# %%
seaborn.set_style('darkgrid')
seaborn.set(rc={'figure.figsize':(11.7,8.27)})
seaborn.barplot(x=cudf_pd.tasks, y=cudf_pd.time, hue=cudf_pd.lib)
# Out:
# <AxesSubplot:xlabel='tasks', ylabel='time'>
